# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1=pd.read_csv("college_1.csv")
df2=pd.read_csv("college_2.csv")
df=pd.concat([df1,df2],join='inner',axis=0)
print(df)
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising
# 0            Computer Science and Engineering       0
# 1            Computer Science and Engineering       0
# 2            Computer Science and Engineering       0
# 3            Computer Science and Engineering       0
# 4            Computer Science and Engineering       0
# ..                                        ...     ...
# 30           Computer Science and Engineering       0
# 31  Electronics and Communication Engineering       0
# 32  Electronics and Communication Engineering       0
# 33           Computer Science and Engineering       0
# 34           Computer Science and Engineering       0
#
# [119 rows x 7 columns]

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
df_new = df[df['CodeKata Score'] < 15000] 
print(df_new)
df_new.to_csv('Exceeded expectations.csv', index=False)
print(pd.read_csv("Exceeded expectations.csv"))
# Out:
#                     Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3            Mugunthan S   100.0   47.0              10610           10610
# 4            Sathammai.S   100.0    8.0               8980            8980
# 5           NIVEESHWAR S   100.0    0.0               8200            8200
# 6          KALAIARASAN K    85.0   47.0               7750            7880
# 7   MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# ..                   ...     ...    ...                ...             ...
# 30         praveen raj j    24.0    0.0               2380            2380
# 31            AMARNATH D    -1.0   12.0               1890            1890
# 32                  bala    32.0    0.0               1720            1720
# 33                  XY Z    -1.0   -1.0                  0               0
# 34             Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising
# 3            Computer Science and Engineering       0
# 4            Computer Science and Engineering       0
# 5            Computer Science and Engineering       0
# 6   Electronics and Communication Engineering     130
# 7            Computer Science and Engineering       0
# ..                                        ...     ...
# 30           Computer Science and Engineering       0
# 31  Electronics and Communication Engineering       0
# 32  Electronics and Communication Engineering       0
# 33           Computer Science and Engineering       0
# 34           Computer Science and Engineering       0
#
# [115 rows x 7 columns]
#                      Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0             Mugunthan S   100.0   47.0              10610           10610
# 1             Sathammai.S   100.0    8.0               8980            8980
# 2            NIVEESHWAR S   100.0    0.0               8200            8200
# 3           KALAIARASAN K    85.0   47.0               7750            7880
# 4    MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# ..                    ...     ...    ...                ...             ...
# 110         praveen raj j    24.0    0.0               2380            2380
# 111            AMARNATH D    -1.0   12.0               1890            1890
# 112                  bala    32.0    0.0               1720            1720
# 113                  XY Z    -1.0   -1.0                  0               0
# 114             Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising
# 0             Computer Science and Engineering       0
# 1             Computer Science and Engineering       0
# 2             Computer Science and Engineering       0
# 3    Electronics and Communication Engineering     130
# 4             Computer Science and Engineering       0
# ..                                         ...     ...
# 110           Computer Science and Engineering       0
# 111  Electronics and Communication Engineering       0
# 112  Electronics and Communication Engineering       0
# 113           Computer Science and Engineering       0
# 114           Computer Science and Engineering       0
#
# [115 rows x 7 columns]

# %%
df_new = df[(df['CodeKata Score'] < 15000) & (df['CodeKata Score'] > 10000)]
print(df_new)
df_new.to_csv('Reached_expectations.csv', index=False)
print(pd.read_csv("Reached_expectations.csv"))
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising
# 3           Computer Science and Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising
# 0           Computer Science and Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0

# %%
df_new = df[(df['CodeKata Score'] < 10000) & (df['CodeKata Score'] > 7000)]
print(df_new)
df_new.to_csv('Needs_Improvement.csv', index=False)
print(pd.read_csv("Needs_Improvement.csv"))
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4              Sathammai.S   100.0    8.0               8980            8980
# 5             NIVEESHWAR S   100.0    0.0               8200            8200
# 6            KALAIARASAN K    85.0   47.0               7750            7880
# 7     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# 11    Balaraman Muthupandi    -1.0    0.0               7670            8050
# 12                JPradhap   100.0    0.0               7340            8030
# 13           SRIRAMKUMAR B    -1.0    0.0               6400            7940
# 14               Praneetha    -1.0  100.0               7170            7730
# 15             Rahul Raj K    -1.0    0.0               6280            7640
# 16                 Guhan S    -1.0   35.0               7310            7630
# 17            Suryarajan S    -1.0   31.0               6710            7550
#
#                                    Department  Rising
# 4            Computer Science and Engineering       0
# 5            Computer Science and Engineering       0
# 6   Electronics and Communication Engineering     130
# 7            Computer Science and Engineering       0
# 4      Electronics and Electrical Engineering       0
# 5            Computer Science and Engineering    1760
# 6            Computer Science and Engineering    1700
# 7   Electronics and Communication Engineering       0
# 8      Electronics and Electrical Engineering    3140
# 9      Electronics and Electrical Engineering    1990
# 10           Computer Science and Engineering     620
# 11           Computer Science and Engineering     380
# 12     Electronics and Electrical Engineering     690
# 13           Computer Science and Engineering    1540
# 14  Electronics and Communication Engineering     560
# 15           Computer Science and Engineering    1360
# 16  Electronics and Communication Engineering     320
# 17           Computer Science and Engineering     840
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0              Sathammai.S   100.0    8.0               8980            8980
# 1             NIVEESHWAR S   100.0    0.0               8200            8200
# 2            KALAIARASAN K    85.0   47.0               7750            7880
# 3     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# 11    Balaraman Muthupandi    -1.0    0.0               7670            8050
# 12                JPradhap   100.0    0.0               7340            8030
# 13           SRIRAMKUMAR B    -1.0    0.0               6400            7940
# 14               Praneetha    -1.0  100.0               7170            7730
# 15             Rahul Raj K    -1.0    0.0               6280            7640
# 16                 Guhan S    -1.0   35.0               7310            7630
# 17            Suryarajan S    -1.0   31.0               6710            7550
#
#                                    Department  Rising
# 0            Computer Science and Engineering       0
# 1            Computer Science and Engineering       0
# 2   Electronics and Communication Engineering     130
# 3            Computer Science and Engineering       0
# 4      Electronics and Electrical Engineering       0
# 5            Computer Science and Engineering    1760
# 6            Computer Science and Engineering    1700
# 7   Electronics and Communication Engineering       0
# 8      Electronics and Electrical Engineering    3140
# 9      Electronics and Electrical Engineering    1990
# 10           Computer Science and Engineering     620
# 11           Computer Science and Engineering     380
# 12     Electronics and Electrical Engineering     690
# 13           Computer Science and Engineering    1540
# 14  Electronics and Communication Engineering     560
# 15           Computer Science and Engineering    1360
# 16  Electronics and Communication Engineering     320
# 17           Computer Science and Engineering     840

# %%
df_new = df[df['CodeKata Score'] < 7000] 
print(df_new)
df_new.to_csv('Unsatisfactory.csv', index=False)
print(pd.read_csv("Unsatisfactory.csv"))
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 30    praveen raj j    24.0   0.00               2380            2380
# 31       AMARNATH D    -1.0  12.00               1890            1890
# 32             bala    32.0   0.00               1720            1720
# 33             XY Z    -1.0  -1.00                  0               0
# 34        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising
# 8   Electronics and Communication Engineering       0
# 9            Computer Science and Engineering       0
# 10  Electronics and Communication Engineering       0
# 11           Computer Science and Engineering       0
# 12           Computer Science and Engineering       0
# ..                                        ...     ...
# 30           Computer Science and Engineering       0
# 31  Electronics and Communication Engineering       0
# 32  Electronics and Communication Engineering       0
# 33           Computer Science and Engineering       0
# 34           Computer Science and Engineering       0
#
# [93 rows x 7 columns]
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        J.SUGANTHI    27.0  50.00               5860            5860
# 1      thamizhpaana    29.0   0.00               5500            5500
# 2   Iyappan Samiraj    50.0  24.00               5400            5400
# 3      Ponniyamma.R   100.0  11.25               5380            5380
# 4         SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 88    praveen raj j    24.0   0.00               2380            2380
# 89       AMARNATH D    -1.0  12.00               1890            1890
# 90             bala    32.0   0.00               1720            1720
# 91             XY Z    -1.0  -1.00                  0               0
# 92        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising
# 0   Electronics and Communication Engineering       0
# 1            Computer Science and Engineering       0
# 2   Electronics and Communication Engineering       0
# 3            Computer Science and Engineering       0
# 4            Computer Science and Engineering       0
# ..                                        ...     ...
# 88           Computer Science and Engineering       0
# 89  Electronics and Communication Engineering       0
# 90  Electronics and Communication Engineering       0
# 91           Computer Science and Engineering       0
# 92           Computer Science and Engineering       0
#
# [93 rows x 7 columns]

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
col = df.loc[: , "Previous Geekions":"CodeKata Score"]
df['mean of pre_greek&codekata'] = col.mean(axis=1)
print(df)
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  \
# 0            Computer Science and Engineering       0
# 1            Computer Science and Engineering       0
# 2            Computer Science and Engineering       0
# 3            Computer Science and Engineering       0
# 4            Computer Science and Engineering       0
# ..                                        ...     ...
# 30           Computer Science and Engineering       0
# 31  Electronics and Communication Engineering       0
# 32  Electronics and Communication Engineering       0
# 33           Computer Science and Engineering       0
# 34           Computer Science and Engineering       0
#
#     mean of pre_greek&codekata
# 0                      24500.0
# 1                      21740.0
# 2                      19680.0
# 3                      10610.0
# 4                       8980.0
# ..                         ...
# 30                      2380.0
# 31                      1890.0
# 32                      1720.0
# 33                         0.0
# 34                         0.0
#
# [119 rows x 8 columns]

# %% [markdown]
# ###### No of students participated

# %%
no_of_student = len(df.axes[0])
print("Number of students: ", no_of_student)
# Out:
# Number of students:  119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
avg_column = df.mean(axis=0)
print (avg_column)
# Out:
# python                          54.352941
# mysql                           23.500000
# Previous Geekions             3842.352941
# CodeKata Score                4051.764706
# Rising                         209.411765
# mean of pre_greek&codekata    3947.058824
# dtype: float64
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10392\510418646.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg_column = df.mean(axis=0)

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df = pd.concat([df,pd.DataFrame(df.sum(axis=1),columns=['Total'])],axis=1)
df4=df.head(3)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10392\305133628.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = pd.concat([df,pd.DataFrame(df.sum(axis=1),columns=['Total'])],axis=1)

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df['rank_greekcoins'] = df['Previous Geekions'].rank(ascending = 0)
print(df)
res=df.head(3)
print("Shining stars of the week ",res)
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  \
# 0            Computer Science and Engineering       0
# 1            Computer Science and Engineering       0
# 2            Computer Science and Engineering       0
# 3            Computer Science and Engineering       0
# 4            Computer Science and Engineering       0
# ..                                        ...     ...
# 30           Computer Science and Engineering       0
# 31  Electronics and Communication Engineering       0
# 32  Electronics and Communication Engineering       0
# 33           Computer Science and Engineering       0
# 34           Computer Science and Engineering       0
#
#     mean of pre_greek&codekata    Total  rank_greekcoins
# 0                      24500.0  73602.0              1.0
# 1                      21740.0  65322.0              2.0
# 2                      19680.0  59240.0              3.0
# 3                      10610.0  31977.0              6.0
# 4                       8980.0  27048.0              9.0
# ..                         ...      ...              ...
# 30                      2380.0   7164.0             61.0
# 31                      1890.0   5681.0             69.0
# 32                      1720.0   5192.0             73.0
# 33                         0.0     -2.0            116.0
# 34                         0.0     -2.0            116.0
#
# [119 rows x 10 columns]
# Shining stars of the week            Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  mean of pre_greek&codekata  \
# 0  Computer Science and Engineering       0                     24500.0
# 1  Computer Science and Engineering       0                     21740.0
# 2  Computer Science and Engineering       0                     19680.0
#
#      Total  rank_greekcoins
# 0  73602.0              1.0
# 1  65322.0              2.0
# 2  59240.0              3.0

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import numpy as np
import matplotlib.pyplot as plt
df.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score',autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='CodeKata Score'>

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df.groupby(['Department']).plot(kind='bar', x='Department', title='Department views', figsize= (11,6))
# Out:
# Department
# Computer Science and Engineering             AxesSubplot(0.125,0.125;0.775x0.755)
# Electronics and Communication Engineering    AxesSubplot(0.125,0.125;0.775x0.755)
# Electronics and Electrical Engineering       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
